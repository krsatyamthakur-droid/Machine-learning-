# %%
def check(x):
    x=x.lower()
    x=x.title()
    print(x)
x="rahul KUMAR sharma"
check(x)
# Out:
# Rahul Kumar Sharma

# %%
list=[45,88,72,91,60]

def total(list):
    sum=0
    for i in range(len(list)):
        sum+=list[i]
    print(sum)
    average=sum//len(list)
    print(average)
total(list)
# Out:
# 356
# 71

# %%
email=input("enter your email")

# %%
#Q1
name=" rahul KUMAR sharma "
name=name.strip().title()
list=name.split()
valid=True

for i in list()
# Out:
#   Cell In[4], line 7
#     for i in list()
#                    ^
# SyntaxError: expected ':'

# %%
Names="james bond"
age=45
print(f"Name of the agent {Names} and age is {age}")
# Out:
# Name of the agent james bond and age is 45

# %%
price=453.353434
print(f"the price is {price: .2f}")
# Out:
# the price is  453.35

# %%
dict={
i:i**2 for i in range(1,11)
}
print(dict)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
