# %% [markdown]
# # 🏍️ **Pandas + Seaborn Practice — Bike Resale Listings**
#
# A website sells used bikes. The owner needs answers from the listings.
#
# Solve each question in the empty cell below it.
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook._
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../Data/bike_resale.csv')
df.head()
# Out:
#   bike_id  brand  age_months  km_driven  owner_count  condition  mileage_kmpl  \
# 0   B4543    TVS          25    14455.0            3  Excellent          40.6
# 1   B4392    TVS          43    26304.0            2       Good          51.2
# 2   B4235  Honda          38     6421.0            1       Good          65.0
# 3   B4319   Hero          14     6531.0            1       Good           NaN
# 4   B4284    TVS         115    80000.0            1       Good          61.8
#
#    service_count insurance  price_thousand sold_in_week
# 0            NaN       Yes            41.6           No
# 1            1.0       Yes            24.1           No
# 2            NaN        No            48.2           No
# 3            NaN       Yes            58.7           No
# 4            0.0        No            12.0          Yes

# %% [markdown]
# # 🎯 **1. Selecting Data**
#
# ### _`df[['a','b']]` → select specific columns | `df[df['col'] == x]` → filter rows | combine conditions with `&` / `|`, each wrapped in `()` | `.sort_values()` → order rows_
#
# ---

# %% [markdown]
# **Q1.1 The website owner wants a short list. Show only the `brand`, `km_driven` and `price_thousand` of the first 10 bikes.**
#
# ---

# %%
df[['brand', 'km_driven', 'price_thousand']].head(10)
# Out:
#            brand  km_driven  price_thousand
# 0            TVS    14455.0            41.6
# 1            TVS    26304.0            24.1
# 2          Honda     6421.0            48.2
# 3           Hero     6531.0            58.7
# 4            TVS    80000.0            12.0
# 5  Royal Enfield     5524.0           153.7
# 6           Hero    22686.0            26.4
# 7         Yamaha    52795.0            12.0
# 8           Hero    78402.0            12.0
# 9            TVS    19605.0            54.8

# %% [markdown]
# **Q1.2 A customer only wants a Royal Enfield. Show all Royal Enfield bikes.**
#
# ---

# %%
df[df['brand'] == 'Royal Enfield']
# Out:
#     bike_id          brand  age_months  km_driven  owner_count  condition  \
# 5     B4533  Royal Enfield           5     5524.0            1       Good
# 10    B4394  Royal Enfield          66    49224.0            1       Good
# 40    B4328  Royal Enfield          16    11870.0            1       Fair
# 75    B4499  Royal Enfield          25     5779.0            1       Good
# 76    B4495  Royal Enfield          62    38138.0            1  Excellent
# 83    B4493  Royal Enfield           5     4125.0            1  Excellent
# 87    B4253  Royal Enfield          44    25018.0            2       Good
# 98    B4217  Royal Enfield          93    63861.0            2       Fair
# 100   B4303  Royal Enfield          66    44668.0            2       Good
# 101   B4154  Royal Enfield          72    57056.0            2       Good
# 102   B4458  Royal Enfield           5     2887.0            1       Good
# 111   B4340  Royal Enfield          85        NaN            1       Good
# 112   B4370  Royal Enfield          14     7284.0            1       Good
# 149   B4152  Royal Enfield          77    47955.0            1  Excellent
# 151   B4230  Royal Enfield          54    27008.0            3       Good
# 162   B4321  Royal Enfield          73    38433.0            1  Excellent
# 163   B4410  Royal Enfield         103    62570.0            1       Good
# 169   B4391  Royal Enfield          58    46540.0            1       Fair
# 174   B4507  Royal Enfield         116    56742.0            1  Excellent
# 182   B4162  Royal Enfield          69    39200.0            3       Fair
# 186   B4444  Royal Enfield          55    39360.0            1  Excellent
# 191   B4312  Royal Enfield          64    41659.0            1  Excellent
# 195   B4389  Royal Enfield          46    25186.0            1       Good
# 202   B4329  Royal Enfield         106    54479.0            1  Excellent
# 209   B4223  Royal Enfield          24    13055.0            1       Good
# 214   B4130  Royal Enfield           5     2268.0            1       Good
# 219   B4549  Royal Enfield          94    55411.0            2       Good
# 223   B4339  Royal Enfield          36    26883.0            1  Excellent
# 234   B4441  Royal Enfield          57    27260.0            2       Good
# 277   B4490  Royal Enfield          67    29194.0            1       Fair
# 326   B4486  Royal Enfield         112    46367.0            1       Good
# 334   B4361  Royal Enfield          18     9306.0            1  Excellent
# 350   B4285  Royal Enfield         108    79162.0            3       Fair
# 351   B4241  Royal Enfield         100    54547.0            1  Excellent
# 367   B4461  Royal Enfield          93    59270.0            2       Good
# 370   B4482  Royal Enfield           4     3710.0            2       Fair
# 372   B4403  Royal Enfield         115    23187.0            1       Fair
# 380   B4375  Royal Enfield         106    60584.0            1       Good
# 385   B4168  Royal Enfield         117    52274.0            2       Good
# 390   B4327  Royal Enfield          27     3404.0            2       Fair
# 401   B4242  Royal Enfield          38    26002.0            2  Excellent
# 408   B4517  Royal Enfield          67    43238.0            1  Excellent
# 419   B4245  Royal Enfield          20    11601.0            2       Good
# 420   B4508  Royal Enfield          82    53741.0            2       Good
# 430   B4225  Royal Enfield          13     8428.0            1       Good
# 432   B4401  Royal Enfield          74    52287.0            1       Good
# 436   B4192  Royal Enfield          40     8184.0            1       Good
# 444   B4539  Royal Enfield          57    33339.0            1  Excellent
#
#      mileage_kmpl  service_count insurance  price_thousand sold_in_week
# 5            46.9            2.0        No           153.7           No
# 10           50.9            3.0        No            38.3          Yes
# 40           62.6            NaN       Yes           130.0           No
# 75           44.1            3.0       Yes           111.0           No
# 76           24.1            3.0       Yes            68.2          Yes
# 83           39.8            1.0       Yes           172.3           No
# 87            NaN            NaN       Yes            75.5          Yes
# 98           51.2            1.0        No            12.0          Yes
# 100          40.8            2.0       Yes            49.7          Yes
# 101          54.0            NaN       Yes            25.5          Yes
# 102          54.9            1.0       Yes           157.1           No
# 111          53.1            3.0       Yes            47.5          Yes
# 112          27.9            5.0        No           134.6           No
# 149          50.9            2.0       Yes            41.5          Yes
# 151          41.3            3.0       Yes            43.1          Yes
# 162          59.7            1.0       Yes            55.8          Yes
# 163          42.1            4.0        No            12.0          Yes
# 169          45.3            5.0       Yes            50.8          Yes
# 174          64.9            4.0        No            15.7          Yes
# 182          43.0            2.0       Yes            20.5          Yes
# 186          51.7            1.0       Yes            80.6          Yes
# 191          63.8            3.0       Yes            60.5          Yes
# 195          57.0            3.0        No            73.8          Yes
# 202          49.7            3.0        No            26.3          Yes
# 209          44.9            1.0       Yes           121.4           No
# 214          46.1            4.0        No           154.4           No
# 219          51.7            4.0       Yes            13.0          Yes
# 223          46.6            0.0        No            97.3          Yes
# 234          48.6            NaN       Yes            53.4          Yes
# 277          56.1            1.0        No            45.2          Yes
# 326          51.9            1.0       Yes            20.7          Yes
# 334          60.2            1.0       Yes           138.1           No
# 350          52.1            3.0       Yes            12.0          Yes
# 351          36.7            2.0        No            20.8          Yes
# 367          60.3            NaN        No            19.0          Yes
# 370          46.9            2.0        No           135.8           No
# 372          42.6            1.0        No            12.0          Yes
# 380          56.6            2.0        No            15.0          Yes
# 385          41.0            3.0       Yes            12.0          Yes
# 390          53.1            4.0        No            97.9           No
# 401          46.4            5.0       Yes            89.9          Yes
# 408          31.9            2.0       Yes            53.3          Yes
# 419          51.8            1.0       Yes           120.7           No
# 420          44.5            4.0        No            23.7          Yes
# 430          55.3            1.0       Yes           148.9           No
# 432          49.9            1.0       Yes            42.1          Yes
# 436          43.5            3.0        No            96.4          Yes
# 444          40.1            NaN       Yes            64.1          Yes

# %% [markdown]
# **Q1.3 How many Royal Enfield bikes are there in total?**
#
# ---

# %%
(df['brand'] == 'Royal Enfield').sum()
# Out:
# np.int64(48)

# %% [markdown]
# **Q1.4 Another customer wants a bike in **Excellent** condition that costs **less than 30 thousand**. Show only the `brand`, `condition` and `price_thousand` of such bikes.**
#
# ---

# %%
df[(df['condition'] == 'Excellent') & (df['price_thousand'] < 30)][['brand', 'condition', 'price_thousand']]
# Out:
#       brand  condition  price_thousand
# 7    Yamaha  Excellent            12.0
# 8      Hero  Excellent            12.0
# 11    Honda  Excellent            12.0
# 26     Hero  Excellent            12.0
# 33    Bajaj  Excellent            17.4
# ..      ...        ...             ...
# 417    Hero  Excellent            12.0
# 418     TVS  Excellent            12.0
# 433    Hero  Excellent            26.7
# 434     TVS  Excellent            12.0
# 438   Bajaj  Excellent            12.0
#
# [67 rows x 3 columns]

# %% [markdown]
# **Q1.5 Use `.sort_values()` to find the 5 cheapest bikes overall. Show only `brand` and `price_thousand`.**
#
# ---

# %%
df.sort_values('price_thousand')[['brand', 'price_thousand']].head(5)
# Out:
#              brand  price_thousand
# 449          Bajaj            12.0
# 161            TVS            12.0
# 359            TVS            12.0
# 163  Royal Enfield            12.0
# 167         Yamaha            12.0

# %% [markdown]
# # 🧹 **2. Cleaning Data**
#
# ### _`.isnull().sum()` → missing values per column | `.duplicated().sum()` → duplicate rows | `.fillna()` → fill missing | `.dropna()` → drop missing_
#
# ---

# %% [markdown]
# **Q2.1 Before sharing the file, the owner wants to know which columns have blank values, and how many in each.**
#
# ---

# %%
df.isnull().sum()
# Out:
# bike_id            0
# brand              0
# age_months         0
# km_driven          9
# owner_count        0
# condition          0
# mileage_kmpl      26
# service_count     74
# insurance          0
# price_thousand     0
# sold_in_week       0
# dtype: int64

# %% [markdown]
# **Q2.2 Check whether the dataset has any repeated (duplicate) rows.**
#
# ---

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Q2.3 Fill the blanks in `mileage_kmpl` with the average mileage.**
#
# ---

# %%
df['mileage_kmpl'] = df['mileage_kmpl'].fillna(df['mileage_kmpl'].mean())
df['mileage_kmpl'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Q2.4 Remove the rows where `km_driven` is blank.**
#
# ---

# %%
df = df.dropna(subset=['km_driven'])
df.shape
# Out:
# (441, 11)

# %% [markdown]
# **Q2.5 Print the shape of `df` after both cleaning steps above.**
#
# ---

# %%
df.shape
# Out:
# (441, 11)

# %% [markdown]
# **Q2.6 Run `.isnull().sum()` again to confirm the blanks you handled are gone.**
#
# ---

# %%
df.isnull().sum()
# Out:
# bike_id            0
# brand              0
# age_months         0
# km_driven          0
# owner_count        0
# condition          0
# mileage_kmpl       0
# service_count     73
# insurance          0
# price_thousand     0
# sold_in_week       0
# dtype: int64

# %% [markdown]
# # 📊 **3. Grouping Data**
#
# ### _`.groupby('col')` → split by group | `.mean()` / `.agg()` → aggregate | `.sort_values()` → order the result | `.value_counts()` → count rows per category_
#
# ---

# %% [markdown]
# **Q3.1 Which brand sells for the most on average? Find the average price of each brand, from highest to lowest.**
#
# ---

# %%
df.groupby('brand')['price_thousand'].mean().sort_values(ascending=False)
# Out:
# brand
# Royal Enfield    68.417021
# TVS              30.814118
# Yamaha           30.487755
# Honda            29.241111
# Bajaj            27.329487
# Hero             25.522826
# Name: price_thousand, dtype: float64

# %% [markdown]
# **Q3.2 For each `condition`, show the average price **and** the number of bikes in one table using `.agg()`.**
#
# ---

# %%
df.groupby('condition')['price_thousand'].agg(['mean', 'count'])
# Out:
#                 mean  count
# condition
# Excellent  36.347692    130
# Fair       26.356604    106
# Good       33.761951    205

# %% [markdown]
# **Q3.3 Which brand has the most bikes listed? Use `.value_counts()` on `brand`.**
#
# ---

# %%
df['brand'].value_counts()
# Out:
# brand
# Hero             92
# Honda            90
# TVS              85
# Bajaj            78
# Yamaha           49
# Royal Enfield    47
# Name: count, dtype: int64

# %% [markdown]
# # 📈 **4. Plotting**
#
# ### _`sns.histplot()` → distribution | `sns.boxplot()` → compare across categories | `sns.countplot(hue=)` → grouped counts | `sns.scatterplot(hue=)` → relationship colored by category | `sns.heatmap()` → correlation matrix_
#
# ---

# %% [markdown]
# **Q4.1 How far have most bikes been driven? Draw the distribution of `km_driven`.**
#
# ---

# %%
sns.histplot(data=df, x='km_driven')
plt.show()

# %% [markdown]
# **Q4.2 For every brand, show how many bikes were sold in the first week and how many were not, using `sns.countplot()` with `hue='sold_in_week'`.**
#
# ---

# %%
sns.countplot(data=df, x='brand', hue='sold_in_week')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Q4.3 A buyer says condition does not change the price. Draw one plot of `price_thousand` for each `condition`.**
#
# ---

# %%
sns.boxplot(data=df, x='condition', y='price_thousand')
plt.show()

# %% [markdown]
# **Q4.4 Looking at the plot above — is the buyer right or wrong? Write your answer as a comment.**
#
# ---

# %%
# The buyer is wrong: price distributions differ across conditions, with Excellent bikes generally costing more than Fair bikes.

# %% [markdown]
# **Q4.5 Draw `age_months` against `price_thousand`, coloured by `sold_in_week`.**
#
# ---

# %%
sns.scatterplot(data=df, x='age_months', y='price_thousand', hue='sold_in_week')
plt.show()

# %% [markdown]
# **Q4.6 Based on that scatter plot — what happens to price as a bike gets older? Write your answer as a comment.**
#
# ---

# %%
# Price generally decreases as a bike gets older.

# %% [markdown]
# **Q4.7 Draw a heatmap of the correlation between the numeric columns.**
#
# ---

# %%
sns.heatmap(df.select_dtypes('number').corr(), annot=True, cmap='coolwarm', center=0)
plt.show()

# %% [markdown]
# **Q4.8 From the heatmap — which two columns move together the most? Write your answer as a comment.**
#
# ---

# %%
# age_months and km_driven move together the most (strongest correlation).
